# %%
# %matplotlib inline
import os,random
from packaging import version
import datetime
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import _pickle as cPickle
# %load_ext tensorboard
import numpy as np
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.2.0

# %%
Xd = cPickle.load(open("2016.04C.multisnr.pkl",'rb'), encoding='latin1')
snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1,0])
X = []  
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod,snr)])
        for i in range(Xd[(mod,snr)].shape[0]):  lbl.append((mod,snr))
X = np.vstack(X)

# %%
np.random.seed(2016)
n_examples = X.shape[0]
n_train = n_examples * 0.5
train_idx = np.random.choice(range(0,int(n_examples)), size=int(n_train), replace=False)
test_idx = list(set(range(0,n_examples))-set(train_idx))
X_train = X[train_idx]
X_test =  X[test_idx]
def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy)+1])
    yy1[np.arange(len(yy)),yy] = 1
    return yy1
Y_train = to_onehot(list(map(lambda x: mods.index(lbl[x][0]), train_idx)))
Y_test = to_onehot(list(map(lambda x: mods.index(lbl[x][0]), test_idx)))

# %%
in_shp = list(X_train.shape[1:])
classes = mods
dr = 0.5 # dropout rate (%)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Reshape(([1]+in_shp), input_shape=in_shp))
model.add(tf.keras.layers.ZeroPadding2D((0, 2), data_format="channels_first"))
model.add(tf.keras.layers.Convolution2D(256, (1, 3), padding='valid', activation="relu", name="conv1", kernel_initializer=tf.keras.initializers.GlorotUniform(), data_format="channels_first"))
model.add(tf.keras.layers.Dropout(dr))
model.add(tf.keras.layers.ZeroPadding2D((0, 2), data_format="channels_first"))
model.add(tf.keras.layers.Convolution2D(80, (2, 3), padding='valid', activation="relu", name="conv2", kernel_initializer=tf.keras.initializers.GlorotUniform(), data_format="channels_first"))
model.add(tf.keras.layers.Dropout(dr))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu', kernel_initializer=tf.keras.initializers.he_normal(), name="dense1"))
model.add(tf.keras.layers.Dropout(dr))
model.add(tf.keras.layers.Dense( len(classes), kernel_initializer=tf.keras.initializers.he_normal(), name="dense2" ))
model.add(tf.keras.layers.Activation('softmax'))
model.add(tf.keras.layers.Reshape([len(classes)]))
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.summary()
nb_epoch = 100  
batch_size = 1024
filepath = "convmodrecnets.wts.h5"
score = model.fit(X_train, Y_train, 
                  verbose = 2, 
                  validation_data = (X_test, Y_test), 
                  epochs=100, 
                  batch_size=batch_size,
                  callbacks = [
                      
                      tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, mode='auto'),
                      tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='auto')
                  ]
                 )
model.load_weights(filepath)
score = model.evaluate(X_test, Y_test, verbose=0, batch_size=batch_size)
print(score)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_2 (Reshape)          (None, 1, 2, 128)         0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 1, 2, 132)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 256, 2, 130)       1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256, 2, 130)       0
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 256, 2, 134)       0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 80, 1, 132)        122960
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 80, 1, 132)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10560)             0
# _________________________________________________________________
# dense1 (Dense)               (None, 256)               2703616
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense2 (Dense)               (None, 11)                2827
# _________________________________________________________________
# activation_1 (Activation)    (None, 11)                0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 11)                0
# =================================================================
# Total params: 2,830,427
# Trainable params: 2,830,427
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 80/80 - 4s - loss: 2.4540 - val_loss: 2.2194
# Epoch 2/100
# 80/80 - 4s - loss: 2.1265 - val_loss: 1.8412
# Epoch 3/100
# 80/80 - 4s - loss: 1.6326 - val_loss: 1.3228
# Epoch 4/100
# 80/80 - 4s - loss: 1.3479 - val_loss: 1.1779
# Epoch 5/100
# 80/80 - 4s - loss: 1.2494 - val_loss: 1.1435
# Epoch 6/100
# 80/80 - 4s - loss: 1.2018 - val_loss: 1.1023
# Epoch 7/100
# 80/80 - 4s - loss: 1.1715 - val_loss: 1.0870
# Epoch 8/100
# 80/80 - 4s - loss: 1.1512 - val_loss: 1.0648
# Epoch 9/100
# 80/80 - 4s - loss: 1.1239 - val_loss: 1.0422
# Epoch 10/100
# 80/80 - 4s - loss: 1.1062 - val_loss: 1.0319
# Epoch 11/100
# 80/80 - 4s - loss: 1.0965 - val_loss: 1.0212
# Epoch 12/100
# 80/80 - 4s - loss: 1.0813 - val_loss: 1.0092
# Epoch 13/100
# 80/80 - 4s - loss: 1.0747 - val_loss: 1.0155
# Epoch 14/100
# 80/80 - 4s - loss: 1.0620 - val_loss: 1.0044
# Epoch 15/100
# 80/80 - 4s - loss: 1.0545 - val_loss: 0.9985
# Epoch 16/100
# 80/80 - 4s - loss: 1.0440 - val_loss: 0.9902
# Epoch 17/100
# 80/80 - 4s - loss: 1.0410 - val_loss: 0.9819
# Epoch 18/100
# 80/80 - 4s - loss: 1.0337 - val_loss: 0.9813
# Epoch 19/100
# 80/80 - 4s - loss: 1.0285 - val_loss: 0.9764
# Epoch 20/100
# 80/80 - 4s - loss: 1.0182 - val_loss: 0.9744
# Epoch 21/100
# 80/80 - 4s - loss: 1.0106 - val_loss: 0.9719
# Epoch 22/100
# 80/80 - 4s - loss: 1.0060 - val_loss: 0.9624
# Epoch 23/100
# 80/80 - 4s - loss: 0.9985 - val_loss: 0.9623
# Epoch 24/100
# 80/80 - 4s - loss: 0.9912 - val_loss: 0.9526
# Epoch 25/100
# 80/80 - 4s - loss: 0.9837 - val_loss: 0.9505
# Epoch 26/100
# 80/80 - 4s - loss: 0.9757 - val_loss: 0.9454
# Epoch 27/100
# 80/80 - 4s - loss: 0.9729 - val_loss: 0.9469
# Epoch 28/100
# 80/80 - 4s - loss: 0.9609 - val_loss: 0.9416
# Epoch 29/100
# 80/80 - 4s - loss: 0.9560 - val_loss: 0.9371
# Epoch 30/100
# 80/80 - 4s - loss: 0.9495 - val_loss: 0.9424
# Epoch 31/100
# 80/80 - 4s - loss: 0.9429 - val_loss: 0.9350
# Epoch 32/100
# 80/80 - 4s - loss: 0.9371 - val_loss: 0.9317
# Epoch 33/100
# 80/80 - 4s - loss: 0.9320 - val_loss: 0.9332
# Epoch 34/100
# 80/80 - 4s - loss: 0.9243 - val_loss: 0.9236
# Epoch 35/100
# 80/80 - 4s - loss: 0.9177 - val_loss: 0.9326
# Epoch 36/100
# 80/80 - 4s - loss: 0.9126 - val_loss: 0.9185
# Epoch 37/100
# 80/80 - 4s - loss: 0.9035 - val_loss: 0.9135
# Epoch 38/100
# 80/80 - 4s - loss: 0.9015 - val_loss: 0.9230
# Epoch 39/100
# 80/80 - 4s - loss: 0.8927 - val_loss: 0.9172
# Epoch 40/100
# 80/80 - 4s - loss: 0.8900 - val_loss: 0.9136
# Epoch 41/100
# 80/80 - 4s - loss: 0.8771 - val_loss: 0.9169
# Epoch 42/100
# 80/80 - 4s - loss: 0.8794 - val_loss: 0.9114
# Epoch 43/100
# 80/80 - 4s - loss: 0.8679 - val_loss: 0.9082
# Epoch 44/100
# 80/80 - 4s - loss: 0.8639 - val_loss: 0.9143
# Epoch 45/100
# 80/80 - 4s - loss: 0.8574 - val_loss: 0.9071
# Epoch 46/100
# 80/80 - 4s - loss: 0.8576 - val_loss: 0.9079
# Epoch 47/100
# 80/80 - 4s - loss: 0.8486 - val_loss: 0.9091
# Epoch 48/100
# 80/80 - 4s - loss: 0.8446 - val_loss: 0.9092
# Epoch 49/100
# 80/80 - 4s - loss: 0.8330 - val_loss: 0.9062
# Epoch 50/100
# 80/80 - 4s - loss: 0.8329 - val_loss: 0.9095
# Epoch 51/100
# 80/80 - 4s - loss: 0.8204 - val_loss: 0.9069
# Epoch 52/100
# 80/80 - 4s - loss: 0.8246 - val_loss: 0.9105
# Epoch 53/100
# 80/80 - 4s - loss: 0.8120 - val_loss: 0.9070
# Epoch 54/100
# 80/80 - 4s - loss: 0.8093 - val_loss: 0.9071
# 0.9061972498893738

# %%
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
acc = {}
for snr in snrs:
    # extract classes @ SNR
    test_SNRs = list(map(lambda x: lbl[x][1], test_idx))
#    print(test_SNRs)
    test_X_i = X_test[np.where(np.array(test_SNRs)==snr)]
    test_Y_i = Y_test[np.where(np.array(test_SNRs)==snr)]    
    test_Y_i_hat = model.predict(test_X_i)
    conf = np.zeros([len(classes),len(classes)])
    confnorm = np.zeros([len(classes),len(classes)])
    for i in range(0,test_X_i.shape[0]):
        j = list(test_Y_i[i,:]).index(1)
        k = int(np.argmax(test_Y_i_hat[i,:]))
        conf[j,k] = conf[j,k] + 1
    for i in range(0,len(classes)):
        confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
    plt.figure()
    plot_confusion_matrix(confnorm, labels=classes, title="ConvNet Confusion Matrix (SNR=%d)"%(snr))
    
    cor = np.sum(np.diag(conf))
    ncor = np.sum(conf) - cor
    print ("Overall Accuracy: ", cor / (cor+ncor))
    acc[snr] = 1.0*cor/(cor+ncor)
# Out:
# Overall Accuracy:  0.15256760109154055
# Overall Accuracy:  0.14991398377979848
# Overall Accuracy:  0.16173570019723865
# Overall Accuracy:  0.1634782608695652
# Overall Accuracy:  0.1833575229801645
# Overall Accuracy:  0.28399311531841653
# Overall Accuracy:  0.49987754102375703
# Overall Accuracy:  0.6744817374136229
# Overall Accuracy:  0.7760403530895335
# Overall Accuracy:  0.9087546239210851
# Overall Accuracy:  0.8962521717547779
# Overall Accuracy:  0.896568748457171
# Overall Accuracy:  0.9294575529068353
# Overall Accuracy:  0.9238165680473372
# Overall Accuracy:  0.8949435444280806
# Overall Accuracy:  0.928923988153998
# Overall Accuracy:  0.9330024813895782
# Overall Accuracy:  0.9095890410958904
# Overall Accuracy:  0.9184528208918453
# Overall Accuracy:  0.9389940239043825
# Text(0.5, 1.0, 'CNN2 Classification Accuracy on RadioML 2016.10 Alpha')

# %%
plt.plot(snrs, list(map(lambda x: acc[x], snrs)))
plt.xlabel("Signal to Noise Ratio")
plt.ylabel("Classification Accuracy")
plt.title("CNN2 Classification Accuracy on RadioML 2016.10 Alpha")
# Out:
# Text(0.5, 1.0, 'CNN2 Classification Accuracy on RadioML 2016.10 Alpha')

# %%
acc = {}
for i in snrs:
    acc[i] = []
def runner(seed):
    np.random.seed(seed)
    nb_epoch = 100  
    batch_size = 1024 
    n_examples = X.shape[0]
    n_train = n_examples * 0.5
    train_idx = np.random.choice(range(0,int(n_examples)), size=int(n_train), replace=False)
    test_idx = list(set(range(0,n_examples))-set(train_idx))
    X_train = X[train_idx]
    X_test =  X[test_idx]
    def to_onehot(yy):
        yy1 = np.zeros([len(yy), max(yy)+1])
        yy1[np.arange(len(yy)),yy] = 1
        return yy1
    Y_train = to_onehot(list(map(lambda x: mods.index(lbl[x][0]), train_idx)))
    Y_test = to_onehot(list(map(lambda x: mods.index(lbl[x][0]), test_idx)))
    in_shp = list(X_train.shape[1:])
    classes = mods
    dr = 0.5 # dropout rate (%)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Reshape(([1]+in_shp), input_shape=in_shp))
    model.add(tf.keras.layers.ZeroPadding2D((0, 2), data_format="channels_first"))
    model.add(tf.keras.layers.Convolution2D(256, (1, 3), padding='valid', activation="relu", name="conv1", kernel_initializer=tf.keras.initializers.GlorotUniform(), data_format="channels_first"))
    model.add(tf.keras.layers.Dropout(dr))
    model.add(tf.keras.layers.ZeroPadding2D((0, 2), data_format="channels_first"))
    model.add(tf.keras.layers.Convolution2D(80, (2, 3), padding='valid', activation="relu", name="conv2", kernel_initializer=tf.keras.initializers.GlorotUniform(), data_format="channels_first"))
    model.add(tf.keras.layers.Dropout(dr))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(256, activation='relu', kernel_initializer=tf.keras.initializers.he_normal(), name="dense1"))
    model.add(tf.keras.layers.Dropout(dr))
    model.add(tf.keras.layers.Dense( len(classes), kernel_initializer=tf.keras.initializers.he_normal(), name="dense2" ))
    model.add(tf.keras.layers.Activation('softmax'))
    model.add(tf.keras.layers.Reshape([len(classes)]))
    model.compile(loss='categorical_crossentropy', optimizer='adam')
#     model.summary()
    filepath = "convmodrecnets_CNN2_0.5.wts_%d.h5"%(seed)
    score = model.fit(X_train, Y_train, 
                      verbose = 2, 
                      validation_data = (X_test, Y_test), 
                      epochs=100, 
                      batch_size=batch_size,
                      callbacks = [
                          tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, mode='auto'),
                          tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='auto')
                      ]
                     )
    model.load_weights(filepath)
    for snr in snrs:
        # extract classes @ SNR
        test_SNRs = list(map(lambda x: lbl[x][1], test_idx))
    #    print(test_SNRs)
        test_X_i = X_test[np.where(np.array(test_SNRs)==snr)]
        test_Y_i = Y_test[np.where(np.array(test_SNRs)==snr)]    
        test_Y_i_hat = model.predict(test_X_i)
        conf = np.zeros([len(classes),len(classes)])
        confnorm = np.zeros([len(classes),len(classes)])
        for i in range(0,test_X_i.shape[0]):
            j = list(test_Y_i[i,:]).index(1)
            k = int(np.argmax(test_Y_i_hat[i,:]))
            conf[j,k] = conf[j,k] + 1
        for i in range(0,len(classes)):
            confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
#         plt.figure()
#         plot_confusion_matrix(confnorm, labels=classes, title="ConvNet Confusion Matrix (SNR=%d)"%(snr))
        cor = np.sum(np.diag(conf))
        ncor = np.sum(conf) - cor
        accuracy = cor / (cor+ncor)
        print ("Overall Accuracy: ", accuracy)
        acc[snr].append(accuracy)

for i in [1947, 1971, 1977, 1999, 2020]:
    runner(i)
# Out:
# Epoch 1/100
# 80/80 - 4s - loss: 2.3827 - val_loss: 1.9501
# Epoch 2/100
# 80/80 - 4s - loss: 1.7295 - val_loss: 1.4617
# Epoch 3/100
# 80/80 - 4s - loss: 1.4402 - val_loss: 1.2498
# Epoch 4/100
# 80/80 - 4s - loss: 1.3018 - val_loss: 1.1697
# Epoch 5/100
# 80/80 - 4s - loss: 1.2389 - val_loss: 1.1410
# Epoch 6/100
# 80/80 - 4s - loss: 1.2042 - val_loss: 1.1122
# Epoch 7/100
# 80/80 - 4s - loss: 1.1818 - val_loss: 1.0955
# Epoch 8/100
# 80/80 - 4s - loss: 1.1508 - val_loss: 1.0656
# Epoch 9/100
# 80/80 - 4s - loss: 1.1264 - val_loss: 1.0354
# Epoch 10/100
# 80/80 - 4s - loss: 1.0929 - val_loss: 1.0272
# Epoch 11/100
# 80/80 - 4s - loss: 1.0725 - val_loss: 1.0124
# Epoch 12/100
# 80/80 - 4s - loss: 1.0570 - val_loss: 0.9984
# Epoch 13/100
# 80/80 - 4s - loss: 1.0446 - val_loss: 0.9878
# Epoch 14/100
# 80/80 - 4s - loss: 1.0359 - val_loss: 0.9829
# Epoch 15/100
# 80/80 - 4s - loss: 1.0256 - val_loss: 0.9795
# Epoch 16/100
# 80/80 - 4s - loss: 1.0152 - val_loss: 0.9683
# Epoch 17/100
# 80/80 - 4s - loss: 1.0104 - val_loss: 0.9688
# Epoch 18/100
# 80/80 - 4s - loss: 1.0026 - val_loss: 0.9657
# Epoch 19/100
# 80/80 - 4s - loss: 0.9919 - val_loss: 0.9602
# Epoch 20/100
# 80/80 - 4s - loss: 0.9891 - val_loss: 0.9581
# Epoch 21/100
# 80/80 - 4s - loss: 0.9800 - val_loss: 0.9510
# Epoch 22/100
# 80/80 - 4s - loss: 0.9741 - val_loss: 0.9556
# Epoch 23/100
# 80/80 - 4s - loss: 0.9698 - val_loss: 0.9470
# Epoch 24/100
# 80/80 - 4s - loss: 0.9625 - val_loss: 0.9414
# Epoch 25/100
# 80/80 - 4s - loss: 0.9511 - val_loss: 0.9352
# Epoch 26/100
# 80/80 - 4s - loss: 0.9470 - val_loss: 0.9402
# Epoch 27/100
# 80/80 - 4s - loss: 0.9435 - val_loss: 0.9332
# Epoch 28/100
# 80/80 - 4s - loss: 0.9394 - val_loss: 0.9326
# Epoch 29/100
# 80/80 - 4s - loss: 0.9318 - val_loss: 0.9277
# Epoch 30/100
# 80/80 - 4s - loss: 0.9254 - val_loss: 0.9288
# Epoch 31/100
# 80/80 - 4s - loss: 0.9178 - val_loss: 0.9285
# Epoch 32/100
# 80/80 - 4s - loss: 0.9162 - val_loss: 0.9287
# Epoch 33/100
# 80/80 - 4s - loss: 0.9078 - val_loss: 0.9244
# Epoch 34/100
# 80/80 - 4s - loss: 0.8999 - val_loss: 0.9239
# Epoch 35/100
# 80/80 - 4s - loss: 0.8973 - val_loss: 0.9220
# Epoch 36/100
# 80/80 - 4s - loss: 0.8904 - val_loss: 0.9254
# Epoch 37/100
# 80/80 - 4s - loss: 0.8879 - val_loss: 0.9181
# Epoch 38/100
# 80/80 - 4s - loss: 0.8793 - val_loss: 0.9194
# Epoch 39/100
# 80/80 - 4s - loss: 0.8740 - val_loss: 0.9181
# Epoch 40/100
# 80/80 - 4s - loss: 0.8691 - val_loss: 0.9147
# Epoch 41/100
# 80/80 - 4s - loss: 0.8648 - val_loss: 0.9137
# Epoch 42/100
# 80/80 - 4s - loss: 0.8625 - val_loss: 0.9160
# Epoch 43/100
# 80/80 - 4s - loss: 0.8487 - val_loss: 0.9158
# Epoch 44/100
# 80/80 - 4s - loss: 0.8480 - val_loss: 0.9224
# Epoch 45/100
# 80/80 - 4s - loss: 0.8395 - val_loss: 0.9152
# Epoch 46/100
# 80/80 - 4s - loss: 0.8379 - val_loss: 0.9165
# Overall Accuracy:  0.1544279092461576
# Overall Accuracy:  0.14772727272727273
# Overall Accuracy:  0.158560794044665
# Overall Accuracy:  0.1619283065512979
# Overall Accuracy:  0.17876278616658547
# Overall Accuracy:  0.2717391304347826
# Overall Accuracy:  0.47640117994100295
# Overall Accuracy:  0.645226639655609
# Overall Accuracy:  0.7478517063589492
# Overall Accuracy:  0.860204335908298
# Overall Accuracy:  0.890734055354994
# Overall Accuracy:  0.8984023964053919
# Overall Accuracy:  0.9205949079909251
# Overall Accuracy:  0.9262515262515263
# Overall Accuracy:  0.9021632251720747
# Overall Accuracy:  0.9227913882702301
# Overall Accuracy:  0.9437359339834959
# Overall Accuracy:  0.9021579205492889
# Overall Accuracy:  0.9382563595949617
# Overall Accuracy:  0.9630092476880779
# Epoch 1/100
# 80/80 - 4s - loss: 2.3585 - val_loss: 2.0261
# Epoch 2/100
# 80/80 - 4s - loss: 1.7984 - val_loss: 1.4508
# Epoch 3/100
# 80/80 - 4s - loss: 1.4382 - val_loss: 1.2380
# Epoch 4/100
# 80/80 - 4s - loss: 1.3074 - val_loss: 1.1684
# Epoch 5/100
# 80/80 - 4s - loss: 1.2547 - val_loss: 1.1335
# Epoch 6/100
# 80/80 - 4s - loss: 1.2204 - val_loss: 1.1037
# Epoch 7/100
# 80/80 - 4s - loss: 1.1936 - val_loss: 1.0857
# Epoch 8/100
# 80/80 - 4s - loss: 1.1746 - val_loss: 1.0704
# Epoch 9/100
# 80/80 - 4s - loss: 1.1525 - val_loss: 1.0593
# Epoch 10/100
# 80/80 - 4s - loss: 1.1369 - val_loss: 1.0416
# Epoch 11/100
# 80/80 - 4s - loss: 1.1194 - val_loss: 1.0277
# Epoch 12/100
# 80/80 - 4s - loss: 1.1082 - val_loss: 1.0250
# Epoch 13/100
# 80/80 - 4s - loss: 1.0948 - val_loss: 1.0164
# Epoch 14/100
# 80/80 - 4s - loss: 1.0910 - val_loss: 1.0189
# Epoch 15/100
# 80/80 - 4s - loss: 1.0794 - val_loss: 1.0071
# Epoch 16/100
# 80/80 - 4s - loss: 1.0708 - val_loss: 0.9951
# Epoch 17/100
# 80/80 - 4s - loss: 1.0580 - val_loss: 0.9945
# Epoch 18/100
# 80/80 - 4s - loss: 1.0504 - val_loss: 0.9842
# Epoch 19/100
# 80/80 - 4s - loss: 1.0419 - val_loss: 0.9828
# Epoch 20/100
# 80/80 - 4s - loss: 1.0371 - val_loss: 0.9732
# Epoch 21/100
# 80/80 - 4s - loss: 1.0312 - val_loss: 0.9868
# Epoch 22/100
# 80/80 - 4s - loss: 1.0251 - val_loss: 0.9813
# Epoch 23/100
# 80/80 - 4s - loss: 1.0235 - val_loss: 0.9670
# Epoch 24/100
# 80/80 - 4s - loss: 1.0165 - val_loss: 0.9737
# Epoch 25/100
# 80/80 - 4s - loss: 1.0108 - val_loss: 0.9604
# Epoch 26/100
# 80/80 - 4s - loss: 1.0045 - val_loss: 0.9574
# Epoch 27/100
# 80/80 - 4s - loss: 1.0009 - val_loss: 0.9743
# Epoch 28/100
# 80/80 - 4s - loss: 0.9944 - val_loss: 0.9604
# Epoch 29/100
# 80/80 - 4s - loss: 0.9907 - val_loss: 0.9591
# Epoch 30/100
# 80/80 - 4s - loss: 0.9867 - val_loss: 0.9538
# Epoch 31/100
# 80/80 - 4s - loss: 0.9776 - val_loss: 0.9488
# Epoch 32/100
# 80/80 - 4s - loss: 0.9688 - val_loss: 0.9534
# Epoch 33/100
# 80/80 - 4s - loss: 0.9652 - val_loss: 0.9440
# Epoch 34/100
# 80/80 - 4s - loss: 0.9610 - val_loss: 0.9415
# Epoch 35/100
# 80/80 - 4s - loss: 0.9556 - val_loss: 0.9478
# Epoch 36/100
# 80/80 - 4s - loss: 0.9521 - val_loss: 0.9378
# Epoch 37/100
# 80/80 - 4s - loss: 0.9430 - val_loss: 0.9382
# Epoch 38/100
# 80/80 - 4s - loss: 0.9347 - val_loss: 0.9333
# Epoch 39/100
# 80/80 - 4s - loss: 0.9349 - val_loss: 0.9315
# Epoch 40/100
# 80/80 - 4s - loss: 0.9291 - val_loss: 0.9269
# Epoch 41/100
# 80/80 - 4s - loss: 0.9181 - val_loss: 0.9298
# Epoch 42/100
# 80/80 - 4s - loss: 0.9151 - val_loss: 0.9271
# Epoch 43/100
# 80/80 - 4s - loss: 0.9085 - val_loss: 0.9286
# Epoch 44/100
# 80/80 - 4s - loss: 0.9033 - val_loss: 0.9240
# Epoch 45/100
# 80/80 - 4s - loss: 0.8992 - val_loss: 0.9259
# Epoch 46/100
# 80/80 - 4s - loss: 0.8964 - val_loss: 0.9211
# Epoch 47/100
# 80/80 - 4s - loss: 0.8915 - val_loss: 0.9221
# Epoch 48/100
# 80/80 - 4s - loss: 0.8838 - val_loss: 0.9208
# Epoch 49/100
# 80/80 - 4s - loss: 0.8777 - val_loss: 0.9183
# Epoch 50/100
# 80/80 - 4s - loss: 0.8714 - val_loss: 0.9201
# Epoch 51/100
# 80/80 - 4s - loss: 0.8692 - val_loss: 0.9185
# Epoch 52/100
# 80/80 - 4s - loss: 0.8669 - val_loss: 0.9183
# Epoch 53/100
# 80/80 - 4s - loss: 0.8609 - val_loss: 0.9180
# Epoch 54/100
# 80/80 - 4s - loss: 0.8557 - val_loss: 0.9161
# Epoch 55/100
# 80/80 - 4s - loss: 0.8532 - val_loss: 0.9115
# Epoch 56/100
# 80/80 - 4s - loss: 0.8489 - val_loss: 0.9138
# Epoch 57/100
# 80/80 - 4s - loss: 0.8404 - val_loss: 0.9146
# Epoch 58/100
# 80/80 - 4s - loss: 0.8384 - val_loss: 0.9133
# Epoch 59/100
# 80/80 - 4s - loss: 0.8320 - val_loss: 0.9154
# Epoch 60/100
# 80/80 - 4s - loss: 0.8306 - val_loss: 0.9164
# Overall Accuracy:  0.1490066225165563
# Overall Accuracy:  0.16032811334824756
# Overall Accuracy:  0.14806710430342815
# Overall Accuracy:  0.15655818540433925
# Overall Accuracy:  0.1849214145383104
# Overall Accuracy:  0.2659890927119484
# Overall Accuracy:  0.4841843088418431
# Overall Accuracy:  0.6689757545769421
# Overall Accuracy:  0.7951895043731778
# Overall Accuracy:  0.8857640617222499
# Overall Accuracy:  0.8637939574046558
# Overall Accuracy:  0.8758839307485979
# Overall Accuracy:  0.9240691165733755
# Overall Accuracy:  0.9223372781065089
# Overall Accuracy:  0.8924704724409449
# Overall Accuracy:  0.9344785276073619
# Overall Accuracy:  0.9333166207069441
# Overall Accuracy:  0.8743289409468034
# Overall Accuracy:  0.9072164948453608
# Overall Accuracy:  0.9389179755671903
# Epoch 1/100
# 80/80 - 4s - loss: 2.4322 - val_loss: 2.1455
# Epoch 2/100
# 80/80 - 4s - loss: 1.8992 - val_loss: 1.4954
# Epoch 3/100
# 80/80 - 4s - loss: 1.4491 - val_loss: 1.2463
# Epoch 4/100
# 80/80 - 4s - loss: 1.3112 - val_loss: 1.1680
# Epoch 5/100
# 80/80 - 4s - loss: 1.2605 - val_loss: 1.1421
# Epoch 6/100
# 80/80 - 4s - loss: 1.2278 - val_loss: 1.1052
# Epoch 7/100
# 80/80 - 4s - loss: 1.1970 - val_loss: 1.0964
# Epoch 8/100
# 80/80 - 4s - loss: 1.1810 - val_loss: 1.0721
# Epoch 9/100
# 80/80 - 4s - loss: 1.1628 - val_loss: 1.0571
# Epoch 10/100
# 80/80 - 4s - loss: 1.1421 - val_loss: 1.0481
# Epoch 11/100
# 80/80 - 4s - loss: 1.1274 - val_loss: 1.0346
# Epoch 12/100
# 80/80 - 4s - loss: 1.1130 - val_loss: 1.0198
# Epoch 13/100
# 80/80 - 4s - loss: 1.0995 - val_loss: 1.0194
# Epoch 14/100
# 80/80 - 4s - loss: 1.0850 - val_loss: 1.0071
# Epoch 15/100
# 80/80 - 4s - loss: 1.0725 - val_loss: 0.9974
# Epoch 16/100
# 80/80 - 4s - loss: 1.0649 - val_loss: 0.9953
# Epoch 17/100
# 80/80 - 4s - loss: 1.0519 - val_loss: 0.9853
# Epoch 18/100
# 80/80 - 4s - loss: 1.0415 - val_loss: 0.9806
# Epoch 19/100
# 80/80 - 4s - loss: 1.0334 - val_loss: 0.9693
# Epoch 20/100
# 80/80 - 4s - loss: 1.0254 - val_loss: 0.9663
# Epoch 21/100
# 80/80 - 4s - loss: 1.0163 - val_loss: 0.9600
# Epoch 22/100
# 80/80 - 4s - loss: 1.0137 - val_loss: 0.9669
# Epoch 23/100
# 80/80 - 4s - loss: 1.0041 - val_loss: 0.9580
# Epoch 24/100
# 80/80 - 4s - loss: 0.9991 - val_loss: 0.9542
# Epoch 25/100
# 80/80 - 4s - loss: 0.9911 - val_loss: 0.9414
# Epoch 26/100
# 80/80 - 4s - loss: 0.9880 - val_loss: 0.9450
# Epoch 27/100
# 80/80 - 4s - loss: 0.9814 - val_loss: 0.9399
# Epoch 28/100
# 80/80 - 4s - loss: 0.9726 - val_loss: 0.9323
# Epoch 29/100
# 80/80 - 4s - loss: 0.9675 - val_loss: 0.9319
# Epoch 30/100
# 80/80 - 4s - loss: 0.9622 - val_loss: 0.9277
# Epoch 31/100
# 80/80 - 4s - loss: 0.9557 - val_loss: 0.9346
# Epoch 32/100
# 80/80 - 4s - loss: 0.9541 - val_loss: 0.9308
# Epoch 33/100
# 80/80 - 4s - loss: 0.9476 - val_loss: 0.9222
# Epoch 34/100
# 80/80 - 4s - loss: 0.9420 - val_loss: 0.9193
# Epoch 35/100
# 80/80 - 4s - loss: 0.9350 - val_loss: 0.9188
# Epoch 36/100
# 80/80 - 4s - loss: 0.9299 - val_loss: 0.9172
# Epoch 37/100
# 80/80 - 4s - loss: 0.9267 - val_loss: 0.9106
# Epoch 38/100
# 80/80 - 4s - loss: 0.9181 - val_loss: 0.9112
# Epoch 39/100
# 80/80 - 4s - loss: 0.9160 - val_loss: 0.9132
# Epoch 40/100
# 80/80 - 4s - loss: 0.9126 - val_loss: 0.9192
# Epoch 41/100
# 80/80 - 4s - loss: 0.9051 - val_loss: 0.9107
# Epoch 42/100
# 80/80 - 4s - loss: 0.9022 - val_loss: 0.9095
# Epoch 43/100
# 80/80 - 4s - loss: 0.8942 - val_loss: 0.9085
# Epoch 44/100
# 80/80 - 4s - loss: 0.8888 - val_loss: 0.9032
# Epoch 45/100
# 80/80 - 4s - loss: 0.8840 - val_loss: 0.9067
# Epoch 46/100
# 80/80 - 4s - loss: 0.8766 - val_loss: 0.9020
# Epoch 47/100
# 80/80 - 4s - loss: 0.8754 - val_loss: 0.9053
# Epoch 48/100
# 80/80 - 4s - loss: 0.8718 - val_loss: 0.9001
# Epoch 49/100
# 80/80 - 4s - loss: 0.8668 - val_loss: 0.9046
# Epoch 50/100
# 80/80 - 4s - loss: 0.8586 - val_loss: 0.9061
# Epoch 51/100
# 80/80 - 4s - loss: 0.8573 - val_loss: 0.8969
# Epoch 52/100
# 80/80 - 4s - loss: 0.8490 - val_loss: 0.8998
# Epoch 53/100
# 80/80 - 4s - loss: 0.8450 - val_loss: 0.9012
# Epoch 54/100
# 80/80 - 4s - loss: 0.8417 - val_loss: 0.8954
# Epoch 55/100
# 80/80 - 4s - loss: 0.8359 - val_loss: 0.8975
# Epoch 56/100
# 80/80 - 4s - loss: 0.8316 - val_loss: 0.8996
# Epoch 57/100
# 80/80 - 4s - loss: 0.8252 - val_loss: 0.8964
# Epoch 58/100
# 80/80 - 4s - loss: 0.8240 - val_loss: 0.8980
# Epoch 59/100
# 80/80 - 4s - loss: 0.8194 - val_loss: 0.8999
# Overall Accuracy:  0.16404886561954624
# Overall Accuracy:  0.14723467862481315
# Overall Accuracy:  0.15451895043731778
# Overall Accuracy:  0.16299232103046818
# Overall Accuracy:  0.1693313953488372
# Overall Accuracy:  0.2814221331997997
# Overall Accuracy:  0.5037869533349622
# Overall Accuracy:  0.6735660847880299
# Overall Accuracy:  0.809369548965861
# Overall Accuracy:  0.9083518107908352
# Overall Accuracy:  0.872561126204001
# Overall Accuracy:  0.906982421875
# Overall Accuracy:  0.9455699292164998
# Overall Accuracy:  0.9369789112309956
# Overall Accuracy:  0.8860727728983688
# Overall Accuracy:  0.9234769687964339
# Overall Accuracy:  0.9398608349900597
# Overall Accuracy:  0.8896930371849264
# Overall Accuracy:  0.9230577689243028
# Overall Accuracy:  0.9507803121248499
# Epoch 1/100
# 80/80 - 4s - loss: 2.3991 - val_loss: 2.0745
# Epoch 2/100
# 80/80 - 4s - loss: 1.8516 - val_loss: 1.5561
# Epoch 3/100
# 80/80 - 4s - loss: 1.5633 - val_loss: 1.3827
# Epoch 4/100
# 80/80 - 4s - loss: 1.4366 - val_loss: 1.2701
# Epoch 5/100
# 80/80 - 4s - loss: 1.3459 - val_loss: 1.1998
# Epoch 6/100
# 80/80 - 4s - loss: 1.2751 - val_loss: 1.1520
# Epoch 7/100
# 80/80 - 4s - loss: 1.2297 - val_loss: 1.1212
# Epoch 8/100
# 80/80 - 4s - loss: 1.2005 - val_loss: 1.1103
# Epoch 9/100
# 80/80 - 4s - loss: 1.1779 - val_loss: 1.0933
# Epoch 10/100
# 80/80 - 4s - loss: 1.1582 - val_loss: 1.0726
# Epoch 11/100
# 80/80 - 4s - loss: 1.1400 - val_loss: 1.0547
# Epoch 12/100
# 80/80 - 4s - loss: 1.1251 - val_loss: 1.0712
# Epoch 13/100
# 80/80 - 4s - loss: 1.1161 - val_loss: 1.0240
# Epoch 14/100
# 80/80 - 4s - loss: 1.0994 - val_loss: 1.0256
# Epoch 15/100
# 80/80 - 4s - loss: 1.0870 - val_loss: 1.0221
# Epoch 16/100
# 80/80 - 4s - loss: 1.0711 - val_loss: 0.9977
# Epoch 17/100
# 80/80 - 4s - loss: 1.0583 - val_loss: 0.9878
# Epoch 18/100
# 80/80 - 4s - loss: 1.0399 - val_loss: 0.9790
# Epoch 19/100
# 80/80 - 4s - loss: 1.0278 - val_loss: 0.9733
# Epoch 20/100
# 80/80 - 4s - loss: 1.0136 - val_loss: 0.9569
# Epoch 21/100
# 80/80 - 4s - loss: 1.0067 - val_loss: 0.9561
# Epoch 22/100
# 80/80 - 4s - loss: 0.9907 - val_loss: 0.9439
# Epoch 23/100
# 80/80 - 4s - loss: 0.9815 - val_loss: 0.9362
# Epoch 24/100
# 80/80 - 4s - loss: 0.9743 - val_loss: 0.9365
# Epoch 25/100
# 80/80 - 4s - loss: 0.9645 - val_loss: 0.9260
# Epoch 26/100
# 80/80 - 4s - loss: 0.9592 - val_loss: 0.9348
# Epoch 27/100
# 80/80 - 4s - loss: 0.9539 - val_loss: 0.9260
# Epoch 28/100
# 80/80 - 4s - loss: 0.9442 - val_loss: 0.9244
# Epoch 29/100
# 80/80 - 4s - loss: 0.9381 - val_loss: 0.9214
# Epoch 30/100
# 80/80 - 4s - loss: 0.9317 - val_loss: 0.9156
# Epoch 31/100
# 80/80 - 4s - loss: 0.9284 - val_loss: 0.9182
# Epoch 32/100
# 80/80 - 4s - loss: 0.9196 - val_loss: 0.9116
# Epoch 33/100
# 80/80 - 4s - loss: 0.9205 - val_loss: 0.9160
# Epoch 34/100
# 80/80 - 4s - loss: 0.9129 - val_loss: 0.9066
# Epoch 35/100
# 80/80 - 4s - loss: 0.9068 - val_loss: 0.9046
# Epoch 36/100
# 80/80 - 4s - loss: 0.9032 - val_loss: 0.9092
# Epoch 37/100
# 80/80 - 4s - loss: 0.9019 - val_loss: 0.9029
# Epoch 38/100
# 80/80 - 4s - loss: 0.8933 - val_loss: 0.9045
# Epoch 39/100
# 80/80 - 4s - loss: 0.8892 - val_loss: 0.8998
# Epoch 40/100
# 80/80 - 4s - loss: 0.8871 - val_loss: 0.9047
# Epoch 41/100
# 80/80 - 4s - loss: 0.8856 - val_loss: 0.8999
# Epoch 42/100
# 80/80 - 4s - loss: 0.8803 - val_loss: 0.8994
# Epoch 43/100
# 80/80 - 4s - loss: 0.8768 - val_loss: 0.9026
# Epoch 44/100
# 80/80 - 4s - loss: 0.8710 - val_loss: 0.8969
# Epoch 45/100
# 80/80 - 4s - loss: 0.8718 - val_loss: 0.9000
# Epoch 46/100
# 80/80 - 4s - loss: 0.8683 - val_loss: 0.8970
# Epoch 47/100
# 80/80 - 4s - loss: 0.8639 - val_loss: 0.8973
# Epoch 48/100
# 80/80 - 4s - loss: 0.8606 - val_loss: 0.8972
# Epoch 49/100
# 80/80 - 4s - loss: 0.8565 - val_loss: 0.8953
# Epoch 50/100
# 80/80 - 4s - loss: 0.8551 - val_loss: 0.8974
# Epoch 51/100
# 80/80 - 4s - loss: 0.8530 - val_loss: 0.8922
# Epoch 52/100
# 80/80 - 4s - loss: 0.8498 - val_loss: 0.8902
# Epoch 53/100
# 80/80 - 4s - loss: 0.8429 - val_loss: 0.8923
# Epoch 54/100
# 80/80 - 4s - loss: 0.8447 - val_loss: 0.8979
# Epoch 55/100
# 80/80 - 4s - loss: 0.8412 - val_loss: 0.8889
# Epoch 56/100
# 80/80 - 4s - loss: 0.8349 - val_loss: 0.8928
# Epoch 57/100
# 80/80 - 4s - loss: 0.8370 - val_loss: 0.8883
# Epoch 58/100
# 80/80 - 4s - loss: 0.8331 - val_loss: 0.8966
# Epoch 59/100
# 80/80 - 4s - loss: 0.8342 - val_loss: 0.8963
# Epoch 60/100
# 80/80 - 4s - loss: 0.8289 - val_loss: 0.8910
# Epoch 61/100
# 80/80 - 4s - loss: 0.8249 - val_loss: 0.8928
# Epoch 62/100
# 80/80 - 4s - loss: 0.8222 - val_loss: 0.8893
# Overall Accuracy:  0.14746430329886756
# Overall Accuracy:  0.15413533834586465
# Overall Accuracy:  0.13818722139673106
# Overall Accuracy:  0.1675531914893617
# Overall Accuracy:  0.21085542771385693
# Overall Accuracy:  0.2872628726287263
# Overall Accuracy:  0.4920909540286703
# Overall Accuracy:  0.6730009871668312
# Overall Accuracy:  0.8094192288921425
# Overall Accuracy:  0.9056603773584906
# Overall Accuracy:  0.9030257936507936
# Overall Accuracy:  0.9197044334975369
# Overall Accuracy:  0.9532383095773943
# Overall Accuracy:  0.9559471365638766
# Overall Accuracy:  0.8966286564204263
# Overall Accuracy:  0.9450332758195711
# Overall Accuracy:  0.9422454568085636
# Overall Accuracy:  0.895193260654113
# Overall Accuracy:  0.9158878504672897
# Overall Accuracy:  0.9417095273083517
# Epoch 1/100
# 80/80 - 4s - loss: 2.4464 - val_loss: 2.2917
# Epoch 2/100
# 80/80 - 4s - loss: 2.1705 - val_loss: 2.0733
# Epoch 3/100
# 80/80 - 4s - loss: 1.8604 - val_loss: 1.5834
# Epoch 4/100
# 80/80 - 4s - loss: 1.6220 - val_loss: 1.4778
# Epoch 5/100
# 80/80 - 4s - loss: 1.5017 - val_loss: 1.3908
# Epoch 6/100
# 80/80 - 4s - loss: 1.4113 - val_loss: 1.2923
# Epoch 7/100
# 80/80 - 4s - loss: 1.3230 - val_loss: 1.2004
# Epoch 8/100
# 80/80 - 4s - loss: 1.2406 - val_loss: 1.1118
# Epoch 9/100
# 80/80 - 4s - loss: 1.1770 - val_loss: 1.0762
# Epoch 10/100
# 80/80 - 4s - loss: 1.1228 - val_loss: 1.0265
# Epoch 11/100
# 80/80 - 4s - loss: 1.0827 - val_loss: 1.0018
# Epoch 12/100
# 80/80 - 4s - loss: 1.0628 - val_loss: 0.9902
# Epoch 13/100
# 80/80 - 4s - loss: 1.0437 - val_loss: 0.9798
# Epoch 14/100
# 80/80 - 4s - loss: 1.0300 - val_loss: 0.9818
# Epoch 15/100
# 80/80 - 4s - loss: 1.0179 - val_loss: 0.9678
# Epoch 16/100
# 80/80 - 4s - loss: 1.0087 - val_loss: 0.9531
# Epoch 17/100
# 80/80 - 4s - loss: 0.9972 - val_loss: 0.9478
# Epoch 18/100
# 80/80 - 4s - loss: 0.9883 - val_loss: 0.9393
# Epoch 19/100
# 80/80 - 4s - loss: 0.9790 - val_loss: 0.9398
# Epoch 20/100
# 80/80 - 4s - loss: 0.9738 - val_loss: 0.9309
# Epoch 21/100
# 80/80 - 4s - loss: 0.9665 - val_loss: 0.9262
# Epoch 22/100
# 80/80 - 4s - loss: 0.9629 - val_loss: 0.9268
# Epoch 23/100
# 80/80 - 4s - loss: 0.9513 - val_loss: 0.9210
# Epoch 24/100
# 80/80 - 4s - loss: 0.9481 - val_loss: 0.9187
# Epoch 25/100
# 80/80 - 4s - loss: 0.9435 - val_loss: 0.9163
# Epoch 26/100
# 80/80 - 4s - loss: 0.9405 - val_loss: 0.9210
# Epoch 27/100
# 80/80 - 4s - loss: 0.9358 - val_loss: 0.9124
# Epoch 28/100
# 80/80 - 4s - loss: 0.9314 - val_loss: 0.9084
# Epoch 29/100
# 80/80 - 4s - loss: 0.9278 - val_loss: 0.9046
# Epoch 30/100
# 80/80 - 4s - loss: 0.9264 - val_loss: 0.9114
# Epoch 31/100
# 80/80 - 4s - loss: 0.9211 - val_loss: 0.9043
# Epoch 32/100
# 80/80 - 4s - loss: 0.9145 - val_loss: 0.9059
# Epoch 33/100
# 80/80 - 4s - loss: 0.9165 - val_loss: 0.9122
# Epoch 34/100
# 80/80 - 4s - loss: 0.9118 - val_loss: 0.9042
# Epoch 35/100
# 80/80 - 4s - loss: 0.9100 - val_loss: 0.9058
# Epoch 36/100
# 80/80 - 4s - loss: 0.9051 - val_loss: 0.9020
# Epoch 37/100
# 80/80 - 4s - loss: 0.8985 - val_loss: 0.8982
# Epoch 38/100
# 80/80 - 4s - loss: 0.8961 - val_loss: 0.9062
# Epoch 39/100
# 80/80 - 4s - loss: 0.8966 - val_loss: 0.9002
# Epoch 40/100
# 80/80 - 4s - loss: 0.8904 - val_loss: 0.8968
# Epoch 41/100
# 80/80 - 4s - loss: 0.8917 - val_loss: 0.9028
# Epoch 42/100
# 80/80 - 4s - loss: 0.8878 - val_loss: 0.8990
# Epoch 43/100
# 80/80 - 4s - loss: 0.8826 - val_loss: 0.8936
# Epoch 44/100
# 80/80 - 4s - loss: 0.8792 - val_loss: 0.8987
# Epoch 45/100
# 80/80 - 4s - loss: 0.8771 - val_loss: 0.8969
# Epoch 46/100
# 80/80 - 4s - loss: 0.8715 - val_loss: 0.9022
# Epoch 47/100
# 80/80 - 4s - loss: 0.8711 - val_loss: 0.8948
# Epoch 48/100
# 80/80 - 4s - loss: 0.8737 - val_loss: 0.8976
# Overall Accuracy:  0.16021825396825398
# Overall Accuracy:  0.14630505100771335
# Overall Accuracy:  0.17123118677522822
# Overall Accuracy:  0.16991576413959086
# Overall Accuracy:  0.20811934458302764
# Overall Accuracy:  0.2921320426904939
# Overall Accuracy:  0.5090641842234199
# Overall Accuracy:  0.6478560867422376
# Overall Accuracy:  0.7438302073050346
# Overall Accuracy:  0.8728505691450714
# Overall Accuracy:  0.8930771125893077
# Overall Accuracy:  0.9135188866799204
# Overall Accuracy:  0.917283950617284
# Overall Accuracy:  0.9513099357390015
# Overall Accuracy:  0.9092036715455222
# Overall Accuracy:  0.9
# Overall Accuracy:  0.9437561942517344
# Overall Accuracy:  0.9187358916478555
# Overall Accuracy:  0.9407242063492064
# Overall Accuracy:  0.9139414802065404

# %%
import matplotlib.pyplot as plt
yerr = []
y = []
x = []
for i in acc:
    yerr.append(np.std(acc[i]))
    y.append(np.mean(acc[i]))
    x.append(i)
# plt.errorbar(x, y, yerr, linestyle='solid', marker='^')
fig, ax = plt.subplots()
ax.errorbar(x, y,
            yerr=yerr,
            fmt='-')

ax.set_xlabel('SNR')
ax.set_ylabel('Accuracy')
ax.set_title('CNN2 Classification Accuracy on RadioML 2016.04 C (with error bars)')
plt.show()

# %%
mean = []
for i in acc:
    mean.append(np.mean(acc[i]))
print(np.mean(mean)*100)
##Average accuracy (87.4 in the paper)
# Out:
# 65.5036989484602
