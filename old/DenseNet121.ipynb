# %%
from fastai import *
from fastai.vision import *
import numpy as np
import os
path = os.getcwd() + '/dataset'
path = Path(path)
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train= 'train', test= 'test', valid_pct=0.2, num_workers=8, bs=128).normalize()
learn = cnn_learner(data, models.densenet121, metrics=[accuracy, error_rate])
data.show_batch(rows=3, figsize=(9,9))

# %%
import torch
print(torch.cuda.get_device_name(0))
torch.cuda.is_available()
# Out:
# GeForce RTX 2080 Ti
# True

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.797618</td>
#       <td>1.663697</td>
#       <td>0.382756</td>
#       <td>0.617244</td>
#       <td>22:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.663265</td>
#       <td>1.592706</td>
#       <td>0.404261</td>
#       <td>0.595739</td>
#       <td>02:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.593752</td>
#       <td>1.541599</td>
#       <td>0.421364</td>
#       <td>0.578636</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.537812</td>
#       <td>1.531672</td>
#       <td>0.425227</td>
#       <td>0.574773</td>
#       <td>03:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.515502</td>
#       <td>1.503122</td>
#       <td>0.437301</td>
#       <td>0.562699</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.480612</td>
#       <td>1.493436</td>
#       <td>0.438153</td>
#       <td>0.561847</td>
#       <td>03:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.466435</td>
#       <td>1.485550</td>
#       <td>0.441136</td>
#       <td>0.558864</td>
#       <td>03:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.451869</td>
#       <td>1.488371</td>
#       <td>0.443977</td>
#       <td>0.556023</td>
#       <td>03:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.405794</td>
#       <td>1.487092</td>
#       <td>0.443750</td>
#       <td>0.556250</td>
#       <td>03:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.416665</td>
#       <td>1.487430</td>
#       <td>0.444176</td>
#       <td>0.555824</td>
#       <td>03:02</td>
#     </tr>
#   </tbody>
# </table>
